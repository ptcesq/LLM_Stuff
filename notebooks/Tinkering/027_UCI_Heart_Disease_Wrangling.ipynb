# %% [markdown]
# ## Simple Notebook
# First notebook on AWS - Experimenatal
# UCI - Heart Disease data set

# %%
import pandas as pd 
import seaborn as sns

# %%
colNames = ["age", "sex", "chest_pain", "rest_bp", "chol", "fasting_blood_sugar>120", "rest_ecg", "max_heart_rate", "exercise_angina", "oldpeak", "slope", "ca", "thal", "heart_disease"]

# %%
fileIn = "./Heart_Disease/processed.cleveland.data"
df1 = pd.read_csv(fileIn, names=colNames, header=None)

# %%
df1["local"] = 1
df1.head()
# Out:
#     age  sex  chest_pain  rest_bp   chol  fasting_blood_sugar>120  rest_ecg  \
# 0  63.0  1.0         1.0    145.0  233.0                      1.0       2.0
# 1  67.0  1.0         4.0    160.0  286.0                      0.0       2.0
# 2  67.0  1.0         4.0    120.0  229.0                      0.0       2.0
# 3  37.0  1.0         3.0    130.0  250.0                      0.0       0.0
# 4  41.0  0.0         2.0    130.0  204.0                      0.0       2.0
#
#    max_heart_rate  exercise_angina  oldpeak  slope   ca thal  heart_disease  \
# 0           150.0              0.0      2.3    3.0  0.0  6.0              0
# 1           108.0              1.0      1.5    2.0  3.0  3.0              2
# 2           129.0              1.0      2.6    2.0  2.0  7.0              1
# 3           187.0              0.0      3.5    3.0  0.0  3.0              0
# 4           172.0              0.0      1.4    1.0  0.0  3.0              0
#
#    local
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
fileIn = "./Heart_Disease/processed.hungarian.data"
df2 = pd.read_csv(fileIn, names=colNames, header=None)
df2["local"] = 2 
df2.head()
# Out:
#    age  sex  chest_pain rest_bp chol fasting_blood_sugar>120 rest_ecg  \
# 0   28    1           2     130  132                       0        2
# 1   29    1           2     120  243                       0        0
# 2   29    1           2     140    ?                       0        0
# 3   30    0           1     170  237                       0        1
# 4   31    0           2     100  219                       0        1
#
#   max_heart_rate exercise_angina  oldpeak slope ca thal  heart_disease  local
# 0            185               0      0.0     ?  ?    ?              0      2
# 1            160               0      0.0     ?  ?    ?              0      2
# 2            170               0      0.0     ?  ?    ?              0      2
# 3            170               0      0.0     ?  ?    6              0      2
# 4            150               0      0.0     ?  ?    ?              0      2

# %%
fileIn = "./Heart_Disease/processed.switzerland.data"
df3 = pd.read_csv(fileIn, names=colNames, header=None)
df3["local"] = 3
df3.head()
# Out:
#    age  sex  chest_pain rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   32    1           1      95     0                       ?        0
# 1   34    1           4     115     0                       ?        ?
# 2   35    1           4       ?     0                       ?        0
# 3   36    1           4     110     0                       ?        0
# 4   38    0           4     105     0                       ?        0
#
#   max_heart_rate exercise_angina oldpeak slope ca thal  heart_disease  local
# 0            127               0      .7     1  ?    ?              1      3
# 1            154               0      .2     1  ?    ?              1      3
# 2            130               1       ?     ?  ?    7              3      3
# 3            125               1       1     2  ?    6              1      3
# 4            166               0     2.8     1  ?    ?              2      3

# %%
fileIn = "./Heart_Disease/processed.va.data"
df4 = pd.read_csv(fileIn, names=colNames, header=None)
df4["local"] = 4
df4.head()
# Out:
#    age  sex  chest_pain rest_bp chol fasting_blood_sugar>120  rest_ecg  \
# 0   63    1           4     140  260                       0         1
# 1   44    1           4     130  209                       0         1
# 2   60    1           4     132  218                       0         1
# 3   55    1           4     142  228                       0         1
# 4   66    1           3     110  213                       1         2
#
#   max_heart_rate exercise_angina oldpeak slope ca thal  heart_disease  local
# 0            112               1       3     2  ?    ?              2      4
# 1            127               0       0     ?  ?    ?              0      4
# 2            140               1     1.5     3  ?    ?              2      4
# 3            149               1     2.5     1  ?    ?              1      4
# 4             99               1     1.3     2  ?    ?              0      4

# %%
frames = [df1, df2, df3]
df = pd.concat(frames)
df.head()
# Out:
#     age  sex  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0  1.0         1.0   145.0  233.0                     1.0      2.0
# 1  67.0  1.0         4.0   160.0  286.0                     0.0      2.0
# 2  67.0  1.0         4.0   120.0  229.0                     0.0      2.0
# 3  37.0  1.0         3.0   130.0  250.0                     0.0      0.0
# 4  41.0  0.0         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    float64
#  2   chest_pain               720 non-null    float64
#  3   rest_bp                  720 non-null    object
#  4   chol                     720 non-null    object
#  5   fasting_blood_sugar>120  720 non-null    object
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 90.0+ KB

# %%
hist = df["heart_disease"].hist(bins=10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    float64
#  2   chest_pain               720 non-null    float64
#  3   rest_bp                  720 non-null    object
#  4   chol                     720 non-null    object
#  5   fasting_blood_sugar>120  720 non-null    object
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 90.0+ KB

# %%
df['sex'] = df['sex'].apply(str).replace('1.0', 'male').replace('0.0', 'female').astype('category')

# %%
df.head()
# Out:
#     age     sex  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0    male         1.0   145.0  233.0                     1.0      2.0
# 1  67.0    male         4.0   160.0  286.0                     0.0      2.0
# 2  67.0    male         4.0   120.0  229.0                     0.0      2.0
# 3  37.0    male         3.0   130.0  250.0                     0.0      0.0
# 4  41.0  female         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    float64
#  3   rest_bp                  720 non-null    object
#  4   chol                     720 non-null    object
#  5   fasting_blood_sugar>120  720 non-null    object
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(1), float64(2), int64(2), object(10)
# memory usage: 85.2+ KB

# %%
df['chest_pain'] = df['chest_pain'].apply(str).replace('1.0', 'typlical').replace('2.0', 'atypical').replace('3.0', 'non-anginal').replace('4.0', 'asymptomatic').astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    object
#  4   chol                     720 non-null    object
#  5   fasting_blood_sugar>120  720 non-null    object
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(2), float64(1), int64(2), object(10)
# memory usage: 80.5+ KB

# %%
df.head()
# Out:
#     age     sex    chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0    male      typlical   145.0  233.0                     1.0      2.0
# 1  67.0    male  asymptomatic   160.0  286.0                     0.0      2.0
# 2  67.0    male  asymptomatic   120.0  229.0                     0.0      2.0
# 3  37.0    male   non-anginal   130.0  250.0                     0.0      0.0
# 4  41.0  female      atypical   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df['rest_bp'] = df['rest_bp'].replace('?', 0).astype('int')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    object
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(3), float64(1), int64(3), object(8)
# memory usage: 75.8+ KB
#     age     sex    chest_pain  rest_bp   chol fasting_blood_sugar>120  \
# 0  63.0    male      typlical      145  233.0                    True
# 1  67.0    male  asymptomatic      160  286.0                   false
# 2  67.0    male  asymptomatic      120  229.0                   false
# 3  37.0    male   non-anginal      130  250.0                   false
# 4  41.0  female      atypical      130  204.0                   false
#
#   rest_ecg max_heart_rate exercise_angina oldpeak slope   ca thal  \
# 0      2.0          150.0             0.0     2.3   3.0  0.0  6.0
# 1      2.0          108.0             1.0     1.5   2.0  3.0  3.0
# 2      2.0          129.0             1.0     2.6   2.0  2.0  7.0
# 3      0.0          187.0             0.0     3.5   3.0  0.0  3.0
# 4      2.0          172.0             0.0     1.4   1.0  0.0  3.0
#
#    heart_disease  local
# 0              0      1
# 1              2      1
# 2              1      1
# 3              0      1
# 4              0      1

# %%
df['chol'] = df['chol'].replace('?', 0).astype('int')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(3), float64(1), int64(4), object(7)
# memory usage: 75.8+ KB
#     age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0    male      typlical      145   233                    True      2.0
# 1  67.0    male  asymptomatic      160   286                   false      2.0
# 2  67.0    male  asymptomatic      120   229                   false      2.0
# 3  37.0    male   non-anginal      130   250                   false      0.0
# 4  41.0  female      atypical      130   204                   false      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df['age'] = df['age'].replace('?', 0).astype('int')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(3), int64(5), object(7)
# memory usage: 75.8+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      2.0
# 1   67    male  asymptomatic      160   286                   false      2.0
# 2   67    male  asymptomatic      120   229                   false      2.0
# 3   37    male   non-anginal      130   250                   false      0.0
# 4   41  female      atypical      130   204                   false      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df['rest_ecg'] = df['rest_ecg'].replace(0.0, 'Normal').replace(1.0, 'abnromal').replace(2.0, 'LVH').astype('category')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(4), int64(5), object(6)
# memory usage: 71.2+ KB
# /tmp/ipykernel_922/4215222960.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['rest_ecg'] = df['rest_ecg'].replace(0.0, 'Normal').replace(1.0, 'abnromal').replace(2.0, 'LVH').astype('category')
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df['fasting_blood_sugar>120'] = df['fasting_blood_sugar>120'].replace(1.0, 'True').replace(0.0, 'false').astype('category')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    float64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    object
#  4   chol                     720 non-null    object
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    object
#  7   max_heart_rate           720 non-null    object
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(3), float64(1), int64(2), object(9)
# memory usage: 75.8+ KB
# /tmp/ipykernel_922/2883498960.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['fasting_blood_sugar>120'] = df['fasting_blood_sugar>120'].replace(1.0, 'True').replace(0.0, 'false').astype('category')
#     age     sex    chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0    male      typlical   145.0  233.0                    True      2.0
# 1  67.0    male  asymptomatic   160.0  286.0                   false      2.0
# 2  67.0    male  asymptomatic   120.0  229.0                   false      2.0
# 3  37.0    male   non-anginal   130.0  250.0                   false      0.0
# 4  41.0  female      atypical   130.0  204.0                   false      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  local
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0      1
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2      1
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1      1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0      1
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0      1

# %%
df['max_heart_rate'] = df['max_heart_rate'].replace('?', 0).astype('int')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    object
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(4), int64(6), object(5)
# memory usage: 71.2+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0             150             0.0     2.3   3.0  0.0  6.0              0
# 1             108             1.0     1.5   2.0  3.0  3.0              2
# 2             129             1.0     2.6   2.0  2.0  7.0              1
# 3             187             0.0     3.5   3.0  0.0  3.0              0
# 4             172             0.0     1.4   1.0  0.0  3.0              0
#
#    local
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df['exercise_angina'] = df['exercise_angina'].replace(1.0, 'True').replace(0.0, 'false').astype('category')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    object
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(5), int64(6), object(4)
# memory usage: 66.5+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0             150           false     2.3   3.0  0.0  6.0              0
# 1             108            True     1.5   2.0  3.0  3.0              2
# 2             129            True     2.6   2.0  2.0  7.0              1
# 3             187           false     3.5   3.0  0.0  3.0              0
# 4             172           false     1.4   1.0  0.0  3.0              0
#
#    local
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df['oldpeak'] = df['oldpeak'].replace('?', 0).astype('float')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    float64
#  10  slope                    720 non-null    object
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(5), float64(1), int64(6), object(3)
# memory usage: 66.5+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina  oldpeak slope   ca thal  heart_disease  \
# 0             150           false      2.3   3.0  0.0  6.0              0
# 1             108            True      1.5   2.0  3.0  3.0              2
# 2             129            True      2.6   2.0  2.0  7.0              1
# 3             187           false      3.5   3.0  0.0  3.0              0
# 4             172           false      1.4   1.0  0.0  3.0              0
#
#    local
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df['slope'] = df['slope'].replace('?', 0).astype('float')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    float64
#  10  slope                    720 non-null    float64
#  11  ca                       720 non-null    object
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(5), float64(2), int64(6), object(2)
# memory usage: 66.5+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina  oldpeak  slope   ca thal  heart_disease  \
# 0             150           false      2.3    3.0  0.0  6.0              0
# 1             108            True      1.5    2.0  3.0  3.0              2
# 2             129            True      2.6    2.0  2.0  7.0              1
# 3             187           false      3.5    3.0  0.0  3.0              0
# 4             172           false      1.4    1.0  0.0  3.0              0
#
#    local
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df['ca'] = df['ca'].replace('?', 0.0).astype('float')
df['ca'] = df['ca'].astype('int')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    float64
#  10  slope                    720 non-null    float64
#  11  ca                       720 non-null    int64
#  12  thal                     720 non-null    object
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(5), float64(2), int64(7), object(1)
# memory usage: 66.5+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina  oldpeak  slope  ca thal  heart_disease  \
# 0             150           false      2.3    3.0   0  6.0              0
# 1             108            True      1.5    2.0   3  3.0              2
# 2             129            True      2.6    2.0   2  7.0              1
# 3             187           false      3.5    3.0   0  3.0              0
# 4             172           false      1.4    1.0   0  3.0              0
#
#    local
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df['thal'] = df['thal'].replace('3.0', 'Normal').replace('6.0', 'Fixed').replace('7.0', 'Defective').astype('category')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    float64
#  10  slope                    720 non-null    float64
#  11  ca                       720 non-null    int64
#  12  thal                     720 non-null    category
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
# dtypes: category(6), float64(2), int64(7)
# memory usage: 61.9 KB
# /tmp/ipykernel_922/2151401433.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['thal'] = df['thal'].replace('3.0', 'Normal').replace('6.0', 'Fixed').replace('7.0', 'Defective').astype('category')
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina  oldpeak  slope  ca       thal  \
# 0             150           false      2.3    3.0   0      Fixed
# 1             108            True      1.5    2.0   3     Normal
# 2             129            True      2.6    2.0   2  Defective
# 3             187           false      3.5    3.0   0     Normal
# 4             172           false      1.4    1.0   0     Normal
#
#    heart_disease  local
# 0              0      1
# 1              2      1
# 2              1      1
# 3              0      1
# 4              0      1

# %%
def fix_target_2(score):
    if score > 0.5:
        return 'False'
    else:
        return 'True'

# %%
# Apply the fix_targe function to the heart_disease column
df['target'] = df['heart_disease'].apply(fix_target_2)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    float64
#  10  slope                    720 non-null    float64
#  11  ca                       720 non-null    int64
#  12  thal                     720 non-null    category
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    int64
#  15  target                   720 non-null    object
# dtypes: category(6), float64(2), int64(7), object(1)
# memory usage: 67.5+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina  oldpeak  slope  ca       thal  \
# 0             150           false      2.3    3.0   0      Fixed
# 1             108            True      1.5    2.0   3     Normal
# 2             129            True      2.6    2.0   2  Defective
# 3             187           false      3.5    3.0   0     Normal
# 4             172           false      1.4    1.0   0     Normal
#
#    heart_disease  local target
# 0              0      1   True
# 1              2      1  False
# 2              1      1  False
# 3              0      1   True
# 4              0      1   True

# %%
df['local'] = df['local'].replace(1, 'Cleveland').replace(2, 'Hungary').replace(3, 'Switzerland').replace(4, 'Virgina').astype('category')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 720 entries, 0 to 122
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      720 non-null    int64
#  1   sex                      720 non-null    category
#  2   chest_pain               720 non-null    category
#  3   rest_bp                  720 non-null    int64
#  4   chol                     720 non-null    int64
#  5   fasting_blood_sugar>120  720 non-null    category
#  6   rest_ecg                 720 non-null    category
#  7   max_heart_rate           720 non-null    int64
#  8   exercise_angina          720 non-null    category
#  9   oldpeak                  720 non-null    float64
#  10  slope                    720 non-null    float64
#  11  ca                       720 non-null    int64
#  12  thal                     720 non-null    category
#  13  heart_disease            720 non-null    int64
#  14  local                    720 non-null    category
#  15  target                   720 non-null    object
# dtypes: category(7), float64(2), int64(6), object(1)
# memory usage: 62.7+ KB
#    age     sex    chest_pain  rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   63    male      typlical      145   233                    True      LVH
# 1   67    male  asymptomatic      160   286                   false      LVH
# 2   67    male  asymptomatic      120   229                   false      LVH
# 3   37    male   non-anginal      130   250                   false   Normal
# 4   41  female      atypical      130   204                   false      LVH
#
#    max_heart_rate exercise_angina  oldpeak  slope  ca       thal  \
# 0             150           false      2.3    3.0   0      Fixed
# 1             108            True      1.5    2.0   3     Normal
# 2             129            True      2.6    2.0   2  Defective
# 3             187           false      3.5    3.0   0     Normal
# 4             172           false      1.4    1.0   0     Normal
#
#    heart_disease      local target
# 0              0  Cleveland   True
# 1              2  Cleveland  False
# 2              1  Cleveland  False
# 3              0  Cleveland   True
# 4              0  Cleveland   True

# %%
import pickle

# %%
fileOut = "./Heart_Disease/sample_heart_data.pkl"
df.to_pickle(fileOut)
