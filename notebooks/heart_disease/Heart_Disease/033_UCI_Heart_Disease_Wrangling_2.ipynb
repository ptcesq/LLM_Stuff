# %% [markdown]
# ## Simple Notebook
# First notebook on AWS - Experimenatal
# UCI - Heart Disease data set

# %%
import pandas as pd 
import sys

# %% [markdown]
# # Environment

# %%
print("Python Version: ", sys.version)
print("Pandas Version: ", pd.__version__)
# Out:
# Python Version:  3.10.13 (main, May 30 2024, 20:38:07) [GCC 9.4.0]
# Pandas Version:  2.2.2

# %%
colNames = ["age", "sex_male", "chest_pain", "rest_bp", "chol", "fasting_blood_sugar>120", "rest_ecg", "max_heart_rate", "exercise_angina", "oldpeak", "slope", "ca", "thal", "heart_disease"]

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.cleveland.data"
df1 = pd.read_csv(fileIn, names=colNames, header=None)

# %%
df1["local"] = "cleveland"
df1.head()
# Out:
#     age  sex_male  chest_pain  rest_bp   chol  fasting_blood_sugar>120  \
# 0  63.0       1.0         1.0    145.0  233.0                      1.0
# 1  67.0       1.0         4.0    160.0  286.0                      0.0
# 2  67.0       1.0         4.0    120.0  229.0                      0.0
# 3  37.0       1.0         3.0    130.0  250.0                      0.0
# 4  41.0       0.0         2.0    130.0  204.0                      0.0
#
#    rest_ecg  max_heart_rate  exercise_angina  oldpeak  slope   ca thal  \
# 0       2.0           150.0              0.0      2.3    3.0  0.0  6.0
# 1       2.0           108.0              1.0      1.5    2.0  3.0  3.0
# 2       2.0           129.0              1.0      2.6    2.0  2.0  7.0
# 3       0.0           187.0              0.0      3.5    3.0  0.0  3.0
# 4       2.0           172.0              0.0      1.4    1.0  0.0  3.0
#
#    heart_disease      local
# 0              0  cleveland
# 1              2  cleveland
# 2              1  cleveland
# 3              0  cleveland
# 4              0  cleveland

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.hungarian.data"
df2 = pd.read_csv(fileIn, names=colNames, header=None)
df2["local"] = "hungary"
df2.head()
# Out:
#    age  sex_male  chest_pain rest_bp chol fasting_blood_sugar>120 rest_ecg  \
# 0   28         1           2     130  132                       0        2
# 1   29         1           2     120  243                       0        0
# 2   29         1           2     140    ?                       0        0
# 3   30         0           1     170  237                       0        1
# 4   31         0           2     100  219                       0        1
#
#   max_heart_rate exercise_angina  oldpeak slope ca thal  heart_disease  \
# 0            185               0      0.0     ?  ?    ?              0
# 1            160               0      0.0     ?  ?    ?              0
# 2            170               0      0.0     ?  ?    ?              0
# 3            170               0      0.0     ?  ?    6              0
# 4            150               0      0.0     ?  ?    ?              0
#
#      local
# 0  hungary
# 1  hungary
# 2  hungary
# 3  hungary
# 4  hungary

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.switzerland.data"
df3 = pd.read_csv(fileIn, names=colNames, header=None)
df3["local"] = "Switzerland"
df3.head()
# Out:
#    age  sex_male  chest_pain rest_bp  chol fasting_blood_sugar>120 rest_ecg  \
# 0   32         1           1      95     0                       ?        0
# 1   34         1           4     115     0                       ?        ?
# 2   35         1           4       ?     0                       ?        0
# 3   36         1           4     110     0                       ?        0
# 4   38         0           4     105     0                       ?        0
#
#   max_heart_rate exercise_angina oldpeak slope ca thal  heart_disease  \
# 0            127               0      .7     1  ?    ?              1
# 1            154               0      .2     1  ?    ?              1
# 2            130               1       ?     ?  ?    7              3
# 3            125               1       1     2  ?    6              1
# 4            166               0     2.8     1  ?    ?              2
#
#          local
# 0  Switzerland
# 1  Switzerland
# 2  Switzerland
# 3  Switzerland
# 4  Switzerland

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.va.data"
df4 = pd.read_csv(fileIn, names=colNames, header=None)
df4["local"] = "virgina"
df4.head()
# Out:
#    age  sex_male  chest_pain rest_bp chol fasting_blood_sugar>120  rest_ecg  \
# 0   63         1           4     140  260                       0         1
# 1   44         1           4     130  209                       0         1
# 2   60         1           4     132  218                       0         1
# 3   55         1           4     142  228                       0         1
# 4   66         1           3     110  213                       1         2
#
#   max_heart_rate exercise_angina oldpeak slope ca thal  heart_disease    local
# 0            112               1       3     2  ?    ?              2  virgina
# 1            127               0       0     ?  ?    ?              0  virgina
# 2            140               1     1.5     3  ?    ?              2  virgina
# 3            149               1     2.5     1  ?    ?              1  virgina
# 4             99               1     1.3     2  ?    ?              0  virgina

# %%
frames = [df1, df2, df3, df4]
df = pd.concat(frames)
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0       1.0         1.0   145.0  233.0                     1.0      2.0
# 1  67.0       1.0         4.0   160.0  286.0                     0.0      2.0
# 2  67.0       1.0         4.0   120.0  229.0                     0.0      2.0
# 3  37.0       1.0         3.0   130.0  250.0                     0.0      0.0
# 4  41.0       0.0         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      920 non-null    float64
#  1   sex_male                 920 non-null    float64
#  2   chest_pain               920 non-null    float64
#  3   rest_bp                  920 non-null    object
#  4   chol                     920 non-null    object
#  5   fasting_blood_sugar>120  920 non-null    object
#  6   rest_ecg                 920 non-null    object
#  7   max_heart_rate           920 non-null    object
#  8   exercise_angina          920 non-null    object
#  9   oldpeak                  920 non-null    object
#  10  slope                    920 non-null    object
#  11  ca                       920 non-null    object
#  12  thal                     920 non-null    object
#  13  heart_disease            920 non-null    int64
#  14  local                    920 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 115.0+ KB

# %%
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0       1.0         1.0   145.0  233.0                     1.0      2.0
# 1  67.0       1.0         4.0   160.0  286.0                     0.0      2.0
# 2  67.0       1.0         4.0   120.0  229.0                     0.0      2.0
# 3  37.0       1.0         3.0   130.0  250.0                     0.0      0.0
# 4  41.0       0.0         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df['sex_male'].replace({0.0: 0, 1.0: 1}, inplace=True)

# %%
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0       1.0         1.0   145.0  233.0                     1.0      2.0
# 1  67.0       1.0         4.0   160.0  286.0                     0.0      2.0
# 2  67.0       1.0         4.0   120.0  229.0                     0.0      2.0
# 3  37.0       1.0         3.0   130.0  250.0                     0.0      0.0
# 4  41.0       0.0         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df.sex_male = df.sex_male.astype(int)

# %%
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0         1         1.0   145.0  233.0                     1.0      2.0
# 1  67.0         1         4.0   160.0  286.0                     0.0      2.0
# 2  67.0         1         4.0   120.0  229.0                     0.0      2.0
# 3  37.0         1         3.0   130.0  250.0                     0.0      0.0
# 4  41.0         0         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df.sex_male = df.sex_male.astype(bool)

# %%
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fasting_blood_sugar>120 rest_ecg  \
# 0  63.0      True         1.0   145.0  233.0                     1.0      2.0
# 1  67.0      True         4.0   160.0  286.0                     0.0      2.0
# 2  67.0      True         4.0   120.0  229.0                     0.0      2.0
# 3  37.0      True         3.0   130.0  250.0                     0.0      0.0
# 4  41.0     False         2.0   130.0  204.0                     0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df['sex_male'] = df['sex'].apply(str).replace('1.0', 1).replace('0.0', 2).astype('bool')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['sex_male'] = df['sex'].apply(str).replace('1.0', 1).replace('0.0', 2).astype('bool')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'sex'

# %%
df.head()

# %%
df.info()

# %%
df['chest_pain'] = df['chest_pain'].apply(str).replace('1.0', 'typlical').replace('2.0', 'atypical').replace('3.0', 'non-anginal').replace('4.0', 'asymptomatic').astype('category')

# %%
df.info()

# %%
df.head()

# %%
df['rest_bp'] = df['rest_bp'].replace('?', 0).astype('int')
df.info()
df.head()

# %%
df['chol'] = df['chol'].replace('?', 0).astype('int')
df.info()
df.head()

# %%
df['age'] = df['age'].replace('?', 0).astype('int')
df.info()
df.head()

# %%
df['rest_ecg'] = df['rest_ecg'].replace(0.0, 'Normal').replace(1.0, 'abnromal').replace(2.0, 'LVH').astype('category')
df.info()
df.head()

# %%
df['fasting_blood_sugar>120'] = df['fasting_blood_sugar>120'].replace(1.0, 'True').replace(0.0, 'false').astype('category')
df.info()
df.head()

# %%
df['max_heart_rate'] = df['max_heart_rate'].replace('?', 0).astype('int')
df.info()
df.head()

# %%
df['exercise_angina'] = df['exercise_angina'].replace(1.0, 'True').replace(0.0, 'false').astype('category')
df.info()
df.head()

# %%
df['oldpeak'] = df['oldpeak'].replace('?', 0).astype('float')
df.info()
df.head()

# %%
df['slope'] = df['slope'].replace('?', 0).astype('float')
df.info()
df.head()

# %%
df['ca'] = df['ca'].replace('?', 0.0).astype('float')
df['ca'] = df['ca'].astype('int')
df.info()
df.head()

# %%
df['thal'] = df['thal'].replace('3.0', 'Normal').replace('6.0', 'Fixed').replace('7.0', 'Defective').astype('category')
df.info()
df.head()

# %%
def fix_target_2(score):
    if score > 0.5:
        return 'False'
    else:
        return 'True'

# %%
# Apply the fix_targe function to the heart_disease column
df['target'] = df['heart_disease'].apply(fix_target_2)
df.info()
df.head()

# %%
df['local'] = df['local'].replace(1, 'Cleveland').replace(2, 'Hungary').replace(3, 'Switzerland').replace(4, 'Virgina').astype('category')
df.info()
df.head()

# %%
import pickle

# %%
fileOut = "./Heart_Disease/sample_heart_data.pkl"
df.to_pickle(fileOut)
