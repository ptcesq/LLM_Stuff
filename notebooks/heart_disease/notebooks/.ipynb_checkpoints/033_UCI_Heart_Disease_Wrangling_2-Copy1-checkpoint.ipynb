# %% [markdown]
# ## Wrangling Notebook
# Environment:  github.com = Codespaces
# UCI - Heart Disease data set

# %%
import pandas as pd 
import sys
import seaborn as sns

# %% [markdown]
# # Environment

# %%
print("Python Version: ", sys.version)
print("Pandas Version: ", pd.__version__)
print('Seaborn Version: ', sns.__version__)
# Out:
# Python Version:  3.10.13 (main, May 30 2024, 20:38:07) [GCC 9.4.0]
# Pandas Version:  2.2.2
# Seaborn Version:  0.13.2

# %%
colNames = ["age", "sex_male", "chest_pain", "rest_bp", "chol", "fbs_lt_120", "rest_ecg", "max_heart_rate", "exercise_angina", "oldpeak", "slope", "ca", "thal", "heart_disease"]

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.cleveland.data"
df1 = pd.read_csv(fileIn, names=colNames, header=None)
df1["local"] = "cleveland"
df1.head()
# Out:
#     age  sex_male  chest_pain  rest_bp   chol  fbs_lt_120  rest_ecg  \
# 0  63.0       1.0         1.0    145.0  233.0         1.0       2.0
# 1  67.0       1.0         4.0    160.0  286.0         0.0       2.0
# 2  67.0       1.0         4.0    120.0  229.0         0.0       2.0
# 3  37.0       1.0         3.0    130.0  250.0         0.0       0.0
# 4  41.0       0.0         2.0    130.0  204.0         0.0       2.0
#
#    max_heart_rate  exercise_angina  oldpeak  slope   ca thal  heart_disease  \
# 0           150.0              0.0      2.3    3.0  0.0  6.0              0
# 1           108.0              1.0      1.5    2.0  3.0  3.0              2
# 2           129.0              1.0      2.6    2.0  2.0  7.0              1
# 3           187.0              0.0      3.5    3.0  0.0  3.0              0
# 4           172.0              0.0      1.4    1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
sns.displot(df1['chest_pain'])

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.hungarian.data"
df2 = pd.read_csv(fileIn, names=colNames, header=None)
df2["local"] = "hungary"
df2.head()
# Out:
#    age  sex_male  chest_pain rest_bp chol fbs_lt_120 rest_ecg max_heart_rate  \
# 0   28         1           2     130  132          0        2            185
# 1   29         1           2     120  243          0        0            160
# 2   29         1           2     140    ?          0        0            170
# 3   30         0           1     170  237          0        1            170
# 4   31         0           2     100  219          0        1            150
#
#   exercise_angina  oldpeak slope ca thal  heart_disease    local
# 0               0      0.0     ?  ?    ?              0  hungary
# 1               0      0.0     ?  ?    ?              0  hungary
# 2               0      0.0     ?  ?    ?              0  hungary
# 3               0      0.0     ?  ?    6              0  hungary
# 4               0      0.0     ?  ?    ?              0  hungary

# %%
sns.displot(df2['chest_pain'])

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.switzerland.data"
df3 = pd.read_csv(fileIn, names=colNames, header=None)
df3["local"] = "Switzerland"
df3.head()
# Out:
#    age  sex_male  chest_pain rest_bp  chol fbs_lt_120 rest_ecg max_heart_rate  \
# 0   32         1           1      95     0          ?        0            127
# 1   34         1           4     115     0          ?        ?            154
# 2   35         1           4       ?     0          ?        0            130
# 3   36         1           4     110     0          ?        0            125
# 4   38         0           4     105     0          ?        0            166
#
#   exercise_angina oldpeak slope ca thal  heart_disease        local
# 0               0      .7     1  ?    ?              1  Switzerland
# 1               0      .2     1  ?    ?              1  Switzerland
# 2               1       ?     ?  ?    7              3  Switzerland
# 3               1       1     2  ?    6              1  Switzerland
# 4               0     2.8     1  ?    ?              2  Switzerland

# %%
sns.displot(df3['chest_pain'])

# %%
fileIn = "/workspaces/LLM_Stuff/notebooks/data/heart_disease/processed.va.data"
df4 = pd.read_csv(fileIn, names=colNames, header=None)
df4["local"] = "virgina"
df4.head()
# Out:
#    age  sex_male  chest_pain rest_bp chol fbs_lt_120  rest_ecg max_heart_rate  \
# 0   63         1           4     140  260          0         1            112
# 1   44         1           4     130  209          0         1            127
# 2   60         1           4     132  218          0         1            140
# 3   55         1           4     142  228          0         1            149
# 4   66         1           3     110  213          1         2             99
#
#   exercise_angina oldpeak slope ca thal  heart_disease    local
# 0               1       3     2  ?    ?              2  virgina
# 1               0       0     ?  ?    ?              0  virgina
# 2               1     1.5     3  ?    ?              2  virgina
# 3               1     2.5     1  ?    ?              1  virgina
# 4               1     1.3     2  ?    ?              0  virgina

# %%
sns.displot(df4['chest_pain'])

# %%
frames = [df1, df2, df3, df4]
df = pd.concat(frames)
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fbs_lt_120 rest_ecg  \
# 0  63.0       1.0         1.0   145.0  233.0        1.0      2.0
# 1  67.0       1.0         4.0   160.0  286.0        0.0      2.0
# 2  67.0       1.0         4.0   120.0  229.0        0.0      2.0
# 3  37.0       1.0         3.0   130.0  250.0        0.0      0.0
# 4  41.0       0.0         2.0   130.0  204.0        0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              920 non-null    float64
#  1   sex_male         920 non-null    float64
#  2   chest_pain       920 non-null    float64
#  3   rest_bp          920 non-null    object
#  4   chol             920 non-null    object
#  5   fbs_lt_120       920 non-null    object
#  6   rest_ecg         920 non-null    object
#  7   max_heart_rate   920 non-null    object
#  8   exercise_angina  920 non-null    object
#  9   oldpeak          920 non-null    object
#  10  slope            920 non-null    object
#  11  ca               920 non-null    object
#  12  thal             920 non-null    object
#  13  heart_disease    920 non-null    int64
#  14  local            920 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 115.0+ KB

# %%
# Convert the sex column 
df.sex_male = df.sex_male.astype(int)
df.sex_male = df.sex_male.astype(bool)
df.head()
# Out:
#     age  sex_male  chest_pain rest_bp   chol fbs_lt_120 rest_ecg  \
# 0  63.0      True         1.0   145.0  233.0        1.0      2.0
# 1  67.0      True         4.0   160.0  286.0        0.0      2.0
# 2  67.0      True         4.0   120.0  229.0        0.0      2.0
# 3  37.0      True         3.0   130.0  250.0        0.0      0.0
# 4  41.0     False         2.0   130.0  204.0        0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
chest_pain_Values = df.chest_pain.to_list()
cpset = set(chest_pain_Values) 
print(cpset)
# Out:
# {1.0, 2.0, 3.0, 4.0}

# %%
# Convert the sex column 
df.chest_pain = df.chest_pain.astype(int)
df.chest_pain = df.chest_pain.astype('category')
df.head()
# Out:
#     age  sex_male chest_pain rest_bp   chol fbs_lt_120 rest_ecg  \
# 0  63.0      True          1   145.0  233.0        1.0      2.0
# 1  67.0      True          4   160.0  286.0        0.0      2.0
# 2  67.0      True          4   120.0  229.0        0.0      2.0
# 3  37.0      True          3   130.0  250.0        0.0      0.0
# 4  41.0     False          2   130.0  204.0        0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              920 non-null    float64
#  1   sex_male         920 non-null    bool
#  2   chest_pain       920 non-null    category
#  3   rest_bp          920 non-null    object
#  4   chol             920 non-null    object
#  5   fbs_lt_120       920 non-null    object
#  6   rest_ecg         920 non-null    object
#  7   max_heart_rate   920 non-null    object
#  8   exercise_angina  920 non-null    object
#  9   oldpeak          920 non-null    object
#  10  slope            920 non-null    object
#  11  ca               920 non-null    object
#  12  thal             920 non-null    object
#  13  heart_disease    920 non-null    int64
#  14  local            920 non-null    object
# dtypes: bool(1), category(1), float64(1), int64(1), object(11)
# memory usage: 102.6+ KB

# %%
df.shape
# Out:
# (920, 15)

# %%
# remove all observations where rest_bp = '?'
df = df[df.rest_bp != '?']
df.shape
# Out:
# (861, 15)

# %%
# Convert the rest_bp column 
df.rest_bp = df.rest_bp.astype(float)
df.rest_bp = df.rest_bp.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 861 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              861 non-null    float64
#  1   sex_male         861 non-null    bool
#  2   chest_pain       861 non-null    category
#  3   rest_bp          861 non-null    int64
#  4   chol             861 non-null    object
#  5   fbs_lt_120       861 non-null    object
#  6   rest_ecg         861 non-null    object
#  7   max_heart_rate   861 non-null    object
#  8   exercise_angina  861 non-null    object
#  9   oldpeak          861 non-null    object
#  10  slope            861 non-null    object
#  11  ca               861 non-null    object
#  12  thal             861 non-null    object
#  13  heart_disease    861 non-null    int64
#  14  local            861 non-null    object
# dtypes: bool(1), category(1), float64(1), int64(2), object(10)
# memory usage: 96.1+ KB

# %%
df.head()
# Out:
#     age  sex_male chest_pain  rest_bp   chol fbs_lt_120 rest_ecg  \
# 0  63.0      True          1      145  233.0        1.0      2.0
# 1  67.0      True          4      160  286.0        0.0      2.0
# 2  67.0      True          4      120  229.0        0.0      2.0
# 3  37.0      True          3      130  250.0        0.0      0.0
# 4  41.0     False          2      130  204.0        0.0      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
# remove all observations where chol = '?'
df = df[df.chol != '?']
df.shape
# Out:
# (834, 15)

# %%
# Convert the rest_bp column 
df.chol = df.chol.astype(float)
df.chol = df.chol.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 834 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              834 non-null    float64
#  1   sex_male         834 non-null    bool
#  2   chest_pain       834 non-null    category
#  3   rest_bp          834 non-null    int64
#  4   chol             834 non-null    int64
#  5   fbs_lt_120       834 non-null    object
#  6   rest_ecg         834 non-null    object
#  7   max_heart_rate   834 non-null    object
#  8   exercise_angina  834 non-null    object
#  9   oldpeak          834 non-null    object
#  10  slope            834 non-null    object
#  11  ca               834 non-null    object
#  12  thal             834 non-null    object
#  13  heart_disease    834 non-null    int64
#  14  local            834 non-null    object
# dtypes: bool(1), category(1), float64(1), int64(3), object(9)
# memory usage: 93.0+ KB

# %%
# remove all observations where chol = '?'
df = df[df.fbs_lt_120 != '?']
df.shape
# Out:
# (745, 15)

# %%
# Convert the fasting_blood_sugar>120 column 
df.fbs_lt_120 = df.fbs_lt_120.astype(float)
df.fbs_lt_120 = df.fbs_lt_120.astype(int)
df.fbs_lt_120 = df.fbs_lt_120.astype(bool)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 745 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              745 non-null    float64
#  1   sex_male         745 non-null    bool
#  2   chest_pain       745 non-null    category
#  3   rest_bp          745 non-null    int64
#  4   chol             745 non-null    int64
#  5   fbs_lt_120       745 non-null    bool
#  6   rest_ecg         745 non-null    object
#  7   max_heart_rate   745 non-null    object
#  8   exercise_angina  745 non-null    object
#  9   oldpeak          745 non-null    object
#  10  slope            745 non-null    object
#  11  ca               745 non-null    object
#  12  thal             745 non-null    object
#  13  heart_disease    745 non-null    int64
#  14  local            745 non-null    object
# dtypes: bool(2), category(1), float64(1), int64(3), object(8)
# memory usage: 78.0+ KB

# %%
df.head()
# Out:
#     age  sex_male chest_pain  rest_bp  chol  fbs_lt_120 rest_ecg  \
# 0  63.0      True          1      145   233        True      2.0
# 1  67.0      True          4      160   286       False      2.0
# 2  67.0      True          4      120   229       False      2.0
# 3  37.0      True          3      130   250       False      0.0
# 4  41.0     False          2      130   204       False      2.0
#
#   max_heart_rate exercise_angina oldpeak slope   ca thal  heart_disease  \
# 0          150.0             0.0     2.3   3.0  0.0  6.0              0
# 1          108.0             1.0     1.5   2.0  3.0  3.0              2
# 2          129.0             1.0     2.6   2.0  2.0  7.0              1
# 3          187.0             0.0     3.5   3.0  0.0  3.0              0
# 4          172.0             0.0     1.4   1.0  0.0  3.0              0
#
#        local
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland

# %%
rest_ecg = df.rest_ecg.to_list()
rest_ecg_set = set(rest_ecg) 
print(rest_ecg_set)
# Out:
# {0.0, 1.0, 2.0, '?', '1', '0', '2'}
